# %%
import pandas as pd
from datetime import datetime
from collections import defaultdict, deque

# Charger le fichier
fichier = "Examen Faculté.xlsx"  # Assurez-vous que ce fichier est dans le même dossier
df_examens = pd.read_excel(fichier, sheet_name="programmation_examens")
df_surveillants = pd.read_excel(fichier, sheet_name="liste_surveillant")

# Préparation des colonnes
df_examens['DATE'] = pd.to_datetime(df_examens['DATE'])
df_examens['HEURE'] = pd.to_datetime(df_examens['HEURE'], format='%H:%M:%S').dt.time
df_examens['DATE_ET_HEURE'] = pd.to_datetime(df_examens['DATE'].astype(str) + ' ' + df_examens['HEURE'].astype(str))

# Détection des créneaux
exam_slots = df_examens[['DATE_ET_HEURE', 'LOCAL']].drop_duplicates().reset_index(drop=True)

def get_required_surveillants(local):
    return 3 if 'AMPHI' in local.upper() else 2

exam_slots['REQUIRED'] = exam_slots['LOCAL'].apply(get_required_surveillants)

# Liste des surveillants
surveillants = df_surveillants['NOM ET PRENOM'].dropna().tolist()
surveillant_queue = deque(surveillants)
surveillance_plan = defaultdict(list)

# Identifier les responsables
responsables = df_examens[df_examens['QUALITE'].str.contains('RESPONSABLE', na=False)][['NOM ET PRENOM', 'DATE']]
responsables_by_day = responsables.groupby('NOM ET PRENOM')['DATE'].apply(set).to_dict()

# Distribution
affectations = []
for _, row in exam_slots.iterrows():
    date_heure = row['DATE_ET_HEURE']
    local = row['LOCAL']
    n_required = row['REQUIRED']
    
    assigned = []
    tries = 0
    while len(assigned) < n_required and tries < len(surveillant_queue) * 2:
        surveillant = surveillant_queue.popleft()
        tries += 1

        if surveillant in responsables_by_day and date_heure.date() in responsables_by_day[surveillant]:
            surveillant_queue.append(surveillant)
            continue
        
        assigned.append(surveillant)
        surveillance_plan[surveillant].append(date_heure)
        surveillant_queue.append(surveillant)
    
    affectations.append({
        'DATE_ET_HEURE': date_heure,
        'LOCAL': local,
        'SURVEILLANTS': assigned
    })

# Intégration dans le tableau original
surveillance_dict = defaultdict(list)
for item in affectations:
    key = (item['DATE_ET_HEURE'], item['LOCAL'])
    surveillance_dict[key] = item['SURVEILLANTS']

def get_surveillants(row):
    key = (pd.to_datetime(row['DATE_ET_HEURE']), row['LOCAL'])
    return ', '.join(surveillance_dict.get(key, []))

df_examens['SURVEILLANTS'] = df_examens.apply(get_surveillants, axis=1)

# Résumé des heures
df_summary = pd.DataFrame([
    {"NOM ET PRENOM": s, "NOMBRE_HEURES": len(h)} for s, h in surveillance_plan.items()
]).sort_values(by="NOMBRE_HEURES", ascending=False)

# Exporter
output = "Répartition_Surveillants_Examen.xlsx"
with pd.ExcelWriter(output, engine='xlsxwriter') as writer:
    df_examens.to_excel(writer, sheet_name="programmation_examens", index=False)
    df_surveillants.to_excel(writer, sheet_name="liste_surveillant", index=False)
    df_summary.to_excel(writer, sheet_name="Résumé_Surveillants", index=False)

print(f"✅ Fichier généré : {output}")
print("\n📋 Répartition complète des surveillants et responsables :\n")

# Regrouper les responsables par (DATE, HEURE, LOCAL)
responsable_map = df_examens[df_examens['QUALITE'].str.contains("RESPONSABLE", na=False)]
responsable_map = responsable_map.groupby(['DATE_ET_HEURE', 'LOCAL'])['NOM ET PRENOM'].first().to_dict()

for a in affectations:
    date_str = a['DATE_ET_HEURE'].strftime("%Y-%m-%d %H:%M")
    local = a['LOCAL']
    surveillants = ', '.join(a['SURVEILLANTS'])
    responsable = responsable_map.get((a['DATE_ET_HEURE'], local), "Aucun")
    
    print(f"{date_str} | {local:<10} → 🧍 Responsable : {responsable} | 👥 Surveillants : {surveillants}")
# Out:
# ✅ Fichier généré : Répartition_Surveillants_Examen.xlsx
#
# 📋 Répartition complète des surveillants et responsables :
#
# 2025-05-14 09:00 | AMPHI A    → 🧍 Responsable : ABIR Abouissaba | 👥 Surveillants : JAZOULI ABDERRAHMANE, AGHBALOU HAMZA, OUAZIK BRAHIM
# 2025-05-14 09:00 | AMPHI B    → 🧍 Responsable : ABIR Abouissaba | 👥 Surveillants : ZAKARIA ELKHATABI, ELIMANI ABDELHAY, Rafik Abdellah
# 2025-05-14 09:00 | AMPHI C    → 🧍 Responsable : OU-YASSINE ALI | 👥 Surveillants : ABDELHAFID FROUDIS, OUBOUDIB YOUB, ZENNOUHI MOHAMED
# 2025-05-14 09:00 | AMPHI S    → 🧍 Responsable : AKHLIL KHALID | 👥 Surveillants : OUZAHIM FATIMA, EL FARKANE LHOUSSAINE, ZIDANE MOHAMMED
# 2025-05-14 09:00 | SALLE S01  → 🧍 Responsable : AIT OUARASSE OTMANE | 👥 Surveillants : FADILI AHMED, GUILMI REDOUANE
# 2025-05-14 09:00 | SALLE S02  → 🧍 Responsable : DARMANE YASSINE | 👥 Surveillants : BOUKDIR MOHAMED, ALAOUI MAMOUNI SMAIL
# 2025-05-14 11:00 | AMPHI A    → 🧍 Responsable : YOUNESS Chawki | 👥 Surveillants : OUDAANI JAOUAD, HADRI AISSAM, DINE-DINE NIHAD
# 2025-05-14 11:00 | AMPHI B    → 🧍 Responsable : YOUNESS Chawki | 👥 Surveillants : BOUGHAZI BRAHIM, SADIK ABDELAZIZ, BOUKDIR ABDELBASSET
# 2025-05-14 11:00 | AMPHI C    → 🧍 Responsable : ABIR Abouissaba | 👥 Surveillants : CHAIB HASSAN, EL OUALI MOURAD, GAOU SALMA
# 2025-05-14 11:00 | AMPHI S    → 🧍 Responsable : YOUNESS Chawki | 👥 Surveillants : LARAQUI MOHAMMED, BEL KASSMI YOUSSEF, BALLOUKI MOHAMED
# 2025-05-14 11:00 | SALLE S01  → 🧍 Responsable : YOUNESS Chawki | 👥 Surveillants : BERRADA YOUSSEF, BAIZ OTMANE
# 2025-05-14 11:00 | SALLE S02  → 🧍 Responsable : HADDOUT YOUSSEF | 👥 Surveillants : EL BASSEM YOUNES, KHARIS ABDEL-ALI
# 2025-05-14 13:00 | AMPHI A    → 🧍 Responsable : HADDOUT YOUSSEF | 👥 Surveillants : EL JAWHARI RABII, RIAD RABIA, KRIT SALAH-DDINE
# 2025-05-20 13:00 | AMPHI B    → 🧍 Responsable : RAFIKI ABDESSAMADE | 👥 Surveillants : BOUKDIR ABDELBASSET, CHAIB HASSAN, EL OUALI MOURAD
# 2025-05-20 13:00 | AMPHI C    → 🧍 Responsable : RAFIKI ABDESSAMADE | 👥 Surveillants : GAOU SALMA, LARAQUI MOHAMMED, BEL KASSMI YOUSSEF
# 2025-05-20 13:00 | AMPHI S    → 🧍 Responsable : BOUAIN ABDELHADI | 👥 Surveillants : BALLOUKI MOHAMED, BERRADA YOUSSEF, BAIZ OTMANE
# 2025-05-20 15:00 | AMPHI A    → 🧍 Responsable : HATIMI SANAA | 👥 Surveillants : EL BASSEM YOUNES, KHARIS ABDEL-ALI, EL JAWHARI RABII
# 2025-05-20 15:00 | AMPHI B    → 🧍 Responsable : HATIMI SANAA | 👥 Surveillants : RIAD RABIA, KRIT SALAH-DDINE, BABA AOMAR
# 2025-05-20 15:00 | AMPHI C    → 🧍 Responsable : HATIMI SANAA | 👥 Surveillants : LMOUCHTER MOHAMED, DBIBIH IMANE, ELLAHYANI AYOUB
# 2025-05-20 15:00 | AMPHI S    → 🧍 Responsable : HATIMI SANAA | 👥 Surveillants : NACIRI ISMAIL, SGHIR SMAIL, BAKCHICH JAWAD
# 2025-05-20 17:00 | AMPHI A    → 🧍 Responsable : EL HANAOUI ESSAADIA | 👥 Surveillants : OUSAID LAHCEN, AKHLIL KHALID, EL JAAFARI ILYAS
# 2025-05-20 17:00 | AMPHI B    → 🧍 Responsable : EL HANAOUI ESSAADIA | 👥 Surveillants : MARCHOUD ZAKARIA, NEJJARI ZAKARIA, AZZAHHAFI HACHIM
# 2025-05-20 17:00 | AMPHI C    → 🧍 Responsable : EL HANAOUI ESSAADIA | 👥 Surveillants : EL GHAZI ABDELLATIF, AIT-TALEB THAMI, DARMANE YASSINE
# 2025-05-20 17:00 | AMPHI S    → 🧍 Responsable : EL HANAOUI ESSAADIA | 👥 Surveillants : EL MAIMOUNI LAHOUCINE, ZIDOUH HAMID, El HABIL BRAHIM
# 2025-05-21 09:00 | AMPHI A    → 🧍 Responsable : HATIMI SANAA | 👥 Surveillants : RAFIKI ABDESSAMADE, EL-MOUDNY SOKAINA, DAKIR RACHID
# 2025-05-21 09:00 | AMPHI B    → 🧍 Responsable : HATIMI SANAA | 👥 Surveillants : TRIBAK HICHAM, SABOUR ABDERRAHMAN, ILMEN SAID
# 2025-05-21 09:00 | AMPHI C    → 🧍 Responsable : HATIMI SANAA | 👥 Surveillants : OMARI KAMAL, HATIMI SANAA, EL HALAOUI ACHRAF
# 2025-05-21 09:00 | AMPHI S    → 🧍 Responsable : DARMANE YASSINE | 👥 Surveillants : BERROUG TARIK, OU-YASSINE ALI, CHERRADI LAILA
# 2025-05-21 09:00 | SALLE S01  → 🧍 Responsable : DARMANE YASSINE | 👥 Surveillants : HADDOUT YOUSSEF, ISMEKH HANANE
# 2025-05-22 09:00 | SALLE S02  → 🧍 Responsable : BOUKDIR ABDELBASSET | 👥 Surveillants : NACIRI ISMAIL, SGHIR SMAIL
# 2025-05-22 11:00 | AMPHI A    → 🧍 Responsable : AKHLIL KHALID | 👥 Surveillants : BAKCHICH JAWAD, OUSAID LAHCEN, AKHLIL KHALID
# 2025-05-22 11:00 | AMPHI B    → 🧍 Responsable : AKHLIL KHALID | 👥 Surveillants : EL JAAFARI ILYAS, MARCHOUD ZAKARIA, NEJJARI ZAKARIA
# 2025-05-22 11:00 | AMPHI C    → 🧍 Responsable : AKHLIL KHALID | 👥 Surveillants : AZZAHHAFI HACHIM, EL GHAZI ABDELLATIF, AIT-TALEB THAMI
# 2025-05-22 11:00 | AMPHI S    → 🧍 Responsable : AKHLIL KHALID | 👥 Surveillants : DARMANE YASSINE, EL MAIMOUNI LAHOUCINE, ZIDOUH HAMID
# 2025-05-22 11:00 | SALLE S01  → 🧍 Responsable : AKHLIL KHALID | 👥 Surveillants : El HABIL BRAHIM, RAFIKI ABDESSAMADE
# 2025-05-22 11:00 | SALLE S02  → 🧍 Responsable : AKHLIL KHALID | 👥 Surveillants : EL-MOUDNY SOKAINA, DAKIR RACHID
# 2025-05-22 13:00 | AMPHI A    → 🧍 Responsable : BOUKDIR MOHAMED | 👥 Surveillants : TRIBAK HICHAM, SABOUR ABDERRAHMAN, ILMEN SAID
# 2025-05-22 13:00 | AMPHI B    → 🧍 Responsable : BOUKDIR MOHAMED | 👥 Surveillants : OMARI KAMAL, HATIMI SANAA, EL HALAOUI ACHRAF
# 2025-05-22 13:00 | AMPHI C    → 🧍 Responsable : BOUKDIR MOHAMED | 👥 Surveillants : BERROUG TARIK, OU-YASSINE ALI, CHERRADI LAILA
# 2025-05-22 13:00 | AMPHI S    → 🧍 Responsable : EL GHAZI ABDELLATIF | 👥 Surveillants : HADDOUT YOUSSEF, ISMEKH HANANE, EL HANAOUI ESSAADIA
# 2025-05-22 13:00 | SALLE S01  → 🧍 Responsable : OUDANI HASSAN | 👥 Surveillants : MOUEDDENE TAOUFIQ, AIT OUARASSE OTMANE
# 2025-05-22 15:00 | AMPHI A    → 🧍 Responsable : BABA AOMAR | 👥 Surveillants : EL MRABET IMANE, ZGOU HSAINE, YOUNESS Chawki
# 2025-05-22 15:00 | AMPHI C    → 🧍 Responsable : OUDAANI JAOUAD | 👥 Surveillants : DRISS AHAJJI, OUDANI HASSAN, JAZOULI ABDERRAHMANE
# 2025-05-22 15:00 | AMPHI S    → 🧍 Responsable : BABA AOMAR | 👥 Surveillants : AGHBALOU HAMZA, OUAZIK BRAHIM, ZAKARIA ELKHATABI
# 2025-05-22 17:00 | AMPHI A    → 🧍 Responsable : EL GHAZI ABDELLATIF | 👥 Surveillants : ELIMANI ABDELHAY, Rafik Abdellah, ABDELHAFID FROUDIS
# 2025-05-22 17:00 | AMPHI C    → 🧍 Responsable : EL GHAZI ABDELLATIF | 👥 Surveillants : OUBOUDIB YOUB, ZENNOUHI MOHAMED, OUZAHIM FATIMA
